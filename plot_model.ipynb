# %%
import keras
from keras.utils import plot_model, custom_object_scope
from keras_self_attention import SeqSelfAttention

# %%
with custom_object_scope({'SeqSelfAttention': SeqSelfAttention}):
    load_model = keras.models.load_model('/Users/dimitrygrebenyuk/Yandex.Disk.localized/Working/PDF/Refinements/PDF-Cluster-Prediction/th_clusters/test_th_groups/tuned_sliced_th_calc_2-12_retrain.h5')

# %%
plot_model(
    load_model,
    to_file="/Users/dimitrygrebenyuk/Yandex.Disk.localized/Working/PDF/Refinements/PDF-Cluster-Prediction/th_clusters/test_th_groups/model_test.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=False,
    rankdir="TB",
    expand_nested=True,
    dpi=90,
    layer_range=None,
    show_layer_activations=True
)

# %%
load_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_2 (Conv1D)           (None, 873, 32)           4128
#
#  batch_normalization_1 (Batc  (None, 873, 32)          128
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 436, 32)          0
#  1D)
#
#  dropout_3 (Dropout)         (None, 436, 32)           0
#
#  conv1d_3 (Conv1D)           (None, 421, 128)          65664
#
#  dropout_4 (Dropout)         (None, 421, 128)          0
#
#  seq_self_attention_1 (SeqSe  (None, 421, 128)         16385
#  lfAttention)
#
#  flatten_1 (Flatten)         (None, 53888)             0
#
#  dense_2 (Dense)             (None, 128)               6897792
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# ...
# Total params: 6,985,387
# Trainable params: 6,985,323
# Non-trainable params: 64
# ...

# %%
with custom_object_scope({'SeqSelfAttention': SeqSelfAttention}):
    load_model = keras.models.load_model('/Users/dimitrygrebenyuk/Yandex.Disk.localized/Working/PDF/Refinements/PDF-Cluster-Prediction/all_data/cifs/new_fold_3_model.hdf5')

# %%
plot_model(
    load_model,
    to_file="/Users/dimitrygrebenyuk/Yandex.Disk.localized/Working/PDF/Refinements/PDF-Cluster-Prediction/th_clusters/test_th_groups/model_csd.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=False,
    rankdir="TB",
    expand_nested=True,
    dpi=400,
    layer_range=None,
    show_layer_activations=True
)

# %%
plot_model(
    load_model,
    to_file="/Users/dimitrygrebenyuk/Yandex.Disk.localized/Working/PDF/Refinements/PDF-Cluster-Prediction/th_clusters/test_th_groups/th_model_no_numbers.png",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=False,
    rankdir="LR",
    expand_nested=False,
    dpi=90,
    layer_range=None,
    show_layer_activations=False
)

# %%
import visualkeras

model = load_model

visualkeras.layered_view(model).show() # display using your system viewer
visualkeras.layered_view(model, to_file='output.png') # write to disk
visualkeras.layered_view(model, to_file='output.png').show() # write and show

visualkeras.layered_view(model)
