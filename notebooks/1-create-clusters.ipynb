# %% [markdown]
# # Stage 1: Create Model Clusters (Notebook Shim)
#
# This thin notebook shim delegates execution to `scripts/s1_create_clusters.py`.
# It preserves the stepwise human control workflow while keeping the underlying logic in a diffable Python script.
#
# **Options:** `--parent ceo2` or `--parent ce40`

# %%
# %run ../scripts/s1_create_clusters.py --parent ceo2
