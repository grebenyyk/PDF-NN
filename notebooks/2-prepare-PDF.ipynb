# %% [markdown]
# # Stage 2: Calculate PDFs (Notebook Shim)
#
# This thin notebook shim delegates execution to `scripts/s2_prepare_pdf.py`.
#
# **Options:** `ceo2`, `ce40`, or `experimental`

# %%
# %run ../scripts/s2_prepare_pdf.py ceo2
